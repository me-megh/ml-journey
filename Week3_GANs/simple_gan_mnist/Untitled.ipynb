# %%
# train.py

import os
import torch
from torch import nn, optim
import torchvision.utils as vutils

from generator import Generator
from discriminator import Discriminator
from utils import get_dataloader

# -----------------------
# 🧠 Hyperparameters
# -----------------------
LATENT_DIM = 100
LR = 0.0002
BATCH_SIZE = 128
EPOCHS = 10  # You can increase this
SAVE_DIR = "outputs"

os.makedirs(SAVE_DIR, exist_ok=True)

# -----------------------
# ⚙️ Device setup
# -----------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"[INFO] Using device: {device}")

# -----------------------
# 📦 Model setup
# -----------------------
G = Generator(LATENT_DIM).to(device)
D = Discriminator().to(device)
criterion = nn.BCELoss()
opt_G = optim.Adam(G.parameters(), lr=LR, betas=(0.5, 0.999))
opt_D = optim.Adam(D.parameters(), lr=LR, betas=(0.5, 0.999))
dataloader = get_dataloader(BATCH_SIZE)

# -----------------------
# 🔁 Training Loop
# -----------------------
for epoch in range(1, EPOCHS + 1):
    for batch_idx, (real_imgs, _) in enumerate(dataloader):
        real_imgs = real_imgs.to(device)
        batch_size = real_imgs.size(0)

        # Labels
        valid = torch.ones(batch_size, 1, device=device)
        fake = torch.zeros(batch_size, 1, device=device)

        # =====================
        # 🎨 Train Generator
        # =====================
        z = torch.randn(batch_size, LATENT_DIM, device=device)
        gen_imgs = G(z)
        g_loss = criterion(D(gen_imgs), valid)

        opt_G.zero_grad()
        g_loss.backward()
        opt_G.step()

        # =====================
        # 🛡️ Train Discriminator
        # =====================
        real_loss = criterion(D(real_imgs), valid)
        fake_loss = criterion(D(gen_imgs.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2

        opt_D.zero_grad()
        d_loss.backward()
        opt_D.step()

        # Logging
        if batch_idx % 100 == 0:
            print(f"[Epoch {epoch}/{EPOCHS}] [Batch {batch_idx}] "
                  f"D loss: {d_loss.item():.4f} | G loss: {g_loss.item():.4f}")

    # Save samples after each epoch
    with torch.no_grad():
        fixed_noise = torch.randn(64, LATENT_DIM, device=device)
        fake_images = G(fixed_noise).detach().cpu()
        save_path = os.path.join(SAVE_DIR, f"fake_samples_epoch_{epoch}.png")
        vutils.save_image(fake_images, save_path, normalize=True, nrow=8)
        print(f"[INFO] Saved sample image to: {save_path}")

print("[✅] Training Complete!")
# Out:
# [INFO] Using device: cpu
# [Epoch 1/10] [Batch 0] D loss: 0.6980 | G loss: 0.7030
# [Epoch 1/10] [Batch 100] D loss: 0.3289 | G loss: 0.9755
# [Epoch 1/10] [Batch 200] D loss: 0.4919 | G loss: 1.2360
# [Epoch 1/10] [Batch 300] D loss: 0.5379 | G loss: 1.3876
# [Epoch 1/10] [Batch 400] D loss: 0.2115 | G loss: 1.6251
# [INFO] Saved sample image to: outputs/fake_samples_epoch_1.png
# [Epoch 2/10] [Batch 0] D loss: 0.2146 | G loss: 1.4610
# [Epoch 2/10] [Batch 100] D loss: 0.2086 | G loss: 1.4788
# [Epoch 2/10] [Batch 200] D loss: 0.3375 | G loss: 1.1571
# [Epoch 2/10] [Batch 300] D loss: 0.1311 | G loss: 1.8697
# [Epoch 2/10] [Batch 400] D loss: 0.1101 | G loss: 2.2844
# [INFO] Saved sample image to: outputs/fake_samples_epoch_2.png
# [Epoch 3/10] [Batch 0] D loss: 0.8677 | G loss: 0.2068
# [Epoch 3/10] [Batch 100] D loss: 0.1658 | G loss: 1.5527
# [Epoch 3/10] [Batch 200] D loss: 0.1906 | G loss: 1.2192
# [Epoch 3/10] [Batch 300] D loss: 0.1978 | G loss: 3.8177
# [Epoch 3/10] [Batch 400] D loss: 0.1073 | G loss: 2.2494
# [INFO] Saved sample image to: outputs/fake_samples_epoch_3.png
# [Epoch 4/10] [Batch 0] D loss: 0.1333 | G loss: 2.0602
# [Epoch 4/10] [Batch 100] D loss: 0.0713 | G loss: 3.1535
# [Epoch 4/10] [Batch 200] D loss: 0.9046 | G loss: 9.8660
# [Epoch 4/10] [Batch 300] D loss: 0.1703 | G loss: 1.5332
# [Epoch 4/10] [Batch 400] D loss: 0.0695 | G loss: 2.8051
# [INFO] Saved sample image to: outputs/fake_samples_epoch_4.png
# [Epoch 5/10] [Batch 0] D loss: 0.1316 | G loss: 2.0251
# [Epoch 5/10] [Batch 100] D loss: 0.0968 | G loss: 3.4969
# [Epoch 5/10] [Batch 200] D loss: 0.3300 | G loss: 0.8158
# [Epoch 5/10] [Batch 300] D loss: 0.0781 | G loss: 2.9583
# [Epoch 5/10] [Batch 400] D loss: 0.1625 | G loss: 2.3697
# [INFO] Saved sample image to: outputs/fake_samples_epoch_5.png
# [Epoch 6/10] [Batch 0] D loss: 0.0954 | G loss: 2.1394
# [Epoch 6/10] [Batch 100] D loss: 0.1179 | G loss: 2.2116
# [Epoch 6/10] [Batch 200] D loss: 0.0519 | G loss: 3.4269
# [Epoch 6/10] [Batch 300] D loss: 0.1319 | G loss: 3.3220
# [Epoch 6/10] [Batch 400] D loss: 0.3206 | G loss: 0.9001
# [INFO] Saved sample image to: outputs/fake_samples_epoch_6.png
# [Epoch 7/10] [Batch 0] D loss: 0.1126 | G loss: 2.7582
# [Epoch 7/10] [Batch 100] D loss: 0.0669 | G loss: 2.3215
# [Epoch 7/10] [Batch 200] D loss: 0.0558 | G loss: 3.6345
# [Epoch 7/10] [Batch 300] D loss: 0.1758 | G loss: 1.4639
# [Epoch 7/10] [Batch 400] D loss: 0.0451 | G loss: 3.2174
# [INFO] Saved sample image to: outputs/fake_samples_epoch_7.png
# [Epoch 8/10] [Batch 0] D loss: 0.1490 | G loss: 1.7166
# [Epoch 8/10] [Batch 100] D loss: 0.1930 | G loss: 1.3225
# [Epoch 8/10] [Batch 200] D loss: 1.4697 | G loss: 12.3573
# [Epoch 8/10] [Batch 300] D loss: 0.0645 | G loss: 2.3559
# [Epoch 8/10] [Batch 400] D loss: 0.1362 | G loss: 3.2762
# [INFO] Saved sample image to: outputs/fake_samples_epoch_8.png
# [Epoch 9/10] [Batch 0] D loss: 0.0441 | G loss: 3.4256
# [Epoch 9/10] [Batch 100] D loss: 0.0787 | G loss: 3.0002
# [Epoch 9/10] [Batch 200] D loss: 0.1169 | G loss: 8.2769
# [Epoch 9/10] [Batch 300] D loss: 0.0692 | G loss: 2.7767
# [Epoch 9/10] [Batch 400] D loss: 0.0673 | G loss: 2.7481
# [INFO] Saved sample image to: outputs/fake_samples_epoch_9.png
# [Epoch 10/10] [Batch 0] D loss: 0.0938 | G loss: 7.2820
# [Epoch 10/10] [Batch 100] D loss: 0.1346 | G loss: 2.0635
# [Epoch 10/10] [Batch 200] D loss: 0.6349 | G loss: 10.4485
# [Epoch 10/10] [Batch 300] D loss: 0.0295 | G loss: 4.0361
# [Epoch 10/10] [Batch 400] D loss: 0.1089 | G loss: 1.9925
# [INFO] Saved sample image to: outputs/fake_samples_epoch_10.png
# [✅] Training Complete!

# %%
# train.py

import os
import torch
from torch import nn, optim
import torchvision.utils as vutils

from generator import Generator
from discriminator import Discriminator
from utils import get_dataloader

# -----------------------
# 🧠 Hyperparameters
# -----------------------
LATENT_DIM = 100
LR = 0.0002
BATCH_SIZE = 128
EPOCHS = 10  # You can increase this
SAVE_DIR = "outputs"

os.makedirs(SAVE_DIR, exist_ok=True)

# -----------------------
# ⚙️ Device setup
# -----------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"[INFO] Using device: {device}")

# -----------------------
# 📦 Model setup
# -----------------------
G = Generator(LATENT_DIM).to(device)
D = Discriminator().to(device)
criterion = nn.BCELoss()
opt_G = optim.Adam(G.parameters(), lr=LR, betas=(0.5, 0.999))
opt_D = optim.Adam(D.parameters(), lr=LR, betas=(0.5, 0.999))
dataloader = get_dataloader(BATCH_SIZE)

# -----------------------
# 🔁 Training Loop
# -----------------------
for epoch in range(1, EPOCHS + 1):
    for batch_idx, (real_imgs, _) in enumerate(dataloader):
        real_imgs = real_imgs.to(device)
        batch_size = real_imgs.size(0)

        # Labels
        valid = torch.ones(batch_size, 1, device=device)
        fake = torch.zeros(batch_size, 1, device=device)

        # =====================
        # 🎨 Train Generator
        # =====================
        z = torch.randn(batch_size, LATENT_DIM, device=device)
        gen_imgs = G(z)
        g_loss = criterion(D(gen_imgs), valid)

        opt_G.zero_grad()
        g_loss.backward()
        opt_G.step()

        # =====================
        # 🛡️ Train Discriminator
        # =====================
        real_loss = criterion(D(real_imgs), valid)
        fake_loss = criterion(D(gen_imgs.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2

        opt_D.zero_grad()
        d_loss.backward()
        opt_D.step()

        # Logging
        if batch_idx % 100 == 0:
            print(f"[Epoch {epoch}/{EPOCHS}] [Batch {batch_idx}] "
                  f"D loss: {d_loss.item():.4f} | G loss: {g_loss.item():.4f}")

    # Save samples after each epoch
    with torch.no_grad():
        fixed_noise = torch.randn(64, LATENT_DIM, device=device)
        fake_images = G(fixed_noise).detach().cpu()
        save_path = os.path.join(SAVE_DIR, f"fake_samples_epoch_{epoch}.png")
        vutils.save_image(fake_images, save_path, normalize=True, nrow=8)
        print(f"[INFO] Saved sample image to: {save_path}")

print("[✅] Training Complete!")
# Out:
# [INFO] Using device: cpu
# [Epoch 1/10] [Batch 0] D loss: 0.6980 | G loss: 0.7030
# [Epoch 1/10] [Batch 100] D loss: 0.3289 | G loss: 0.9755
# [Epoch 1/10] [Batch 200] D loss: 0.4919 | G loss: 1.2360
# [Epoch 1/10] [Batch 300] D loss: 0.5379 | G loss: 1.3876
# [Epoch 1/10] [Batch 400] D loss: 0.2115 | G loss: 1.6251
# [INFO] Saved sample image to: outputs/fake_samples_epoch_1.png
# [Epoch 2/10] [Batch 0] D loss: 0.2146 | G loss: 1.4610
# [Epoch 2/10] [Batch 100] D loss: 0.2086 | G loss: 1.4788
# [Epoch 2/10] [Batch 200] D loss: 0.3375 | G loss: 1.1571
# [Epoch 2/10] [Batch 300] D loss: 0.1311 | G loss: 1.8697
# [Epoch 2/10] [Batch 400] D loss: 0.1101 | G loss: 2.2844
# [INFO] Saved sample image to: outputs/fake_samples_epoch_2.png
# [Epoch 3/10] [Batch 0] D loss: 0.8677 | G loss: 0.2068
# [Epoch 3/10] [Batch 100] D loss: 0.1658 | G loss: 1.5527
# [Epoch 3/10] [Batch 200] D loss: 0.1906 | G loss: 1.2192
# [Epoch 3/10] [Batch 300] D loss: 0.1978 | G loss: 3.8177
# [Epoch 3/10] [Batch 400] D loss: 0.1073 | G loss: 2.2494
# [INFO] Saved sample image to: outputs/fake_samples_epoch_3.png
# [Epoch 4/10] [Batch 0] D loss: 0.1333 | G loss: 2.0602
# [Epoch 4/10] [Batch 100] D loss: 0.0713 | G loss: 3.1535
# [Epoch 4/10] [Batch 200] D loss: 0.9046 | G loss: 9.8660
# [Epoch 4/10] [Batch 300] D loss: 0.1703 | G loss: 1.5332
# [Epoch 4/10] [Batch 400] D loss: 0.0695 | G loss: 2.8051
# [INFO] Saved sample image to: outputs/fake_samples_epoch_4.png
# [Epoch 5/10] [Batch 0] D loss: 0.1316 | G loss: 2.0251
# [Epoch 5/10] [Batch 100] D loss: 0.0968 | G loss: 3.4969
# [Epoch 5/10] [Batch 200] D loss: 0.3300 | G loss: 0.8158
# [Epoch 5/10] [Batch 300] D loss: 0.0781 | G loss: 2.9583
# [Epoch 5/10] [Batch 400] D loss: 0.1625 | G loss: 2.3697
# [INFO] Saved sample image to: outputs/fake_samples_epoch_5.png
# [Epoch 6/10] [Batch 0] D loss: 0.0954 | G loss: 2.1394
# [Epoch 6/10] [Batch 100] D loss: 0.1179 | G loss: 2.2116
# [Epoch 6/10] [Batch 200] D loss: 0.0519 | G loss: 3.4269
# [Epoch 6/10] [Batch 300] D loss: 0.1319 | G loss: 3.3220
# [Epoch 6/10] [Batch 400] D loss: 0.3206 | G loss: 0.9001
# [INFO] Saved sample image to: outputs/fake_samples_epoch_6.png
# [Epoch 7/10] [Batch 0] D loss: 0.1126 | G loss: 2.7582
# [Epoch 7/10] [Batch 100] D loss: 0.0669 | G loss: 2.3215
# [Epoch 7/10] [Batch 200] D loss: 0.0558 | G loss: 3.6345
# [Epoch 7/10] [Batch 300] D loss: 0.1758 | G loss: 1.4639
# [Epoch 7/10] [Batch 400] D loss: 0.0451 | G loss: 3.2174
# [INFO] Saved sample image to: outputs/fake_samples_epoch_7.png
# [Epoch 8/10] [Batch 0] D loss: 0.1490 | G loss: 1.7166
# [Epoch 8/10] [Batch 100] D loss: 0.1930 | G loss: 1.3225
# [Epoch 8/10] [Batch 200] D loss: 1.4697 | G loss: 12.3573
# [Epoch 8/10] [Batch 300] D loss: 0.0645 | G loss: 2.3559
# [Epoch 8/10] [Batch 400] D loss: 0.1362 | G loss: 3.2762
# [INFO] Saved sample image to: outputs/fake_samples_epoch_8.png
# [Epoch 9/10] [Batch 0] D loss: 0.0441 | G loss: 3.4256
# [Epoch 9/10] [Batch 100] D loss: 0.0787 | G loss: 3.0002
# [Epoch 9/10] [Batch 200] D loss: 0.1169 | G loss: 8.2769
# [Epoch 9/10] [Batch 300] D loss: 0.0692 | G loss: 2.7767
# [Epoch 9/10] [Batch 400] D loss: 0.0673 | G loss: 2.7481
# [INFO] Saved sample image to: outputs/fake_samples_epoch_9.png
# [Epoch 10/10] [Batch 0] D loss: 0.0938 | G loss: 7.2820
# [Epoch 10/10] [Batch 100] D loss: 0.1346 | G loss: 2.0635
# [Epoch 10/10] [Batch 200] D loss: 0.6349 | G loss: 10.4485
# [Epoch 10/10] [Batch 300] D loss: 0.0295 | G loss: 4.0361
# [Epoch 10/10] [Batch 400] D loss: 0.1089 | G loss: 1.9925
# [INFO] Saved sample image to: outputs/fake_samples_epoch_10.png
# [✅] Training Complete!
