# %%
# !git clone https://github.com/me-megh/ml-journey.git
# Out:
# Cloning into 'ml-journey'...
# remote: Enumerating objects: 202605, done.
# remote: Total 202605 (delta 0), reused 0 (delta 0), pack-reused 202605 (from 3)
# Receiving objects: 100% (202605/202605), 1.34 GiB | 29.79 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# Updating files: 100% (202714/202714), done.

# %%
# %cd ml-journey/Week4_VAE/mini_gan_faces
# Out:
# /content/ml-journey/Week4_VAE/mini_gan_faces

# %%
# %cd ml-journey/Week4_VAE/mini_gan_faces
# !ls
# Out:
# [Errno 2] No such file or directory: 'ml-journey/Week4_VAE/mini_gan_faces'
# /content/ml-journey/Week4_VAE/mini_gan_faces
#  data	  outputs	       train_GAN_Face.py   Untitled.ipynb
#  models  'requirements.txt '   train.py		   utils

# %%
# !python train.py
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Epoch 1/25:   0% 0/1583 [00:14<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/ml-journey/Week4_VAE/mini_gan_faces/train.py", line 80, in <module>
#     train()
#   File "/content/ml-journey/Week4_VAE/mini_gan_faces/train.py", line 66, in train
#     G_loss.backward()
#   File "/usr/local/lib/python3.11/dist-packages/torch/_tensor.py", line 626, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py", line 347, in backward
#     _engine_run_backward(
# ...

# %%
# !python train.py
